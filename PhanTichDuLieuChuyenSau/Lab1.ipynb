# %% [markdown]
# <a href="https://colab.research.google.com/github/Thuy-code/DulieuChuyensau/blob/readme-edits/PhanTichDuLieuChuyenSau/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
dr = pd.read_csv("https://raw.githubusercontent.com/Thuy-code/DulieuChuyensau/readme-edits/DATA/dulieuxettuyendaihoc.csv", index_col = 'STT')
dr
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT  DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F NaN  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M NaN    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M NaN    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M NaN    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M NaN  2NT  4.25  4.50  5.00   A
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ..  ..  ...   ...   ...   ...  ..
# 96   8.6  6.9  7.4  8.8  7.6  5.8  7.3  ...   F NaN    1  5.25  1.50  6.25   C
# 97   3.7  5.4  6.0  5.1  5.5  3.9  6.1  ...   F NaN    1  5.25  3.75  4.75   C
# 98   8.8  5.5  7.4  7.7  6.2  7.3  8.1  ...   M NaN  2NT  7.00  8.00  4.00   C
# 99   2.7  1.8  3.4  5.3  4.5  7.9  4.9  ...   M NaN    1  5.00  3.50  5.50   C
# ...

# %% [markdown]
# 3.

# %%
dr.head(10)
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT  DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F NaN  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M NaN    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M NaN    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M NaN    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M NaN  2NT  4.25  4.50  5.00   A
# 6    9.3  7.6  7.9  8.6  7.0  7.3  7.7  ...   M NaN    1  1.50  4.00  6.00  D1
# 7    2.8  3.9  5.5  6.9  5.0  7.3  4.6  ...   F NaN    2  6.50  6.75  5.25   C
# 8    8.3  6.0  7.6  5.1  7.5  4.7  5.8  ...   F NaN    2  3.75  4.50  4.25  D1
# 9    6.5  6.3  7.6  6.0  5.5  7.1  6.3  ...   F NaN    1  3.50  3.50  6.75  D1
# 10   7.3  5.9  4.7  7.1  6.7  7.9  6.7  ...   F NaN    1  4.00  4.75  5.50  D1
#
# [10 rows x 55 columns]

# %%
dr.tail(10)
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT  DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 91   8.1  7.7  9.1  8.5  6.1  8.6  8.8  ...   M NaN    2  6.25  4.00  6.50   A
# 92   7.8  6.5  6.7  5.4  6.2  4.8  5.9  ...   M NaN  2NT  4.75  4.75  4.50   A
# 93   5.0  6.6  6.5  7.2  5.8  6.7  6.4  ...   M NaN    1  3.25  5.25  4.25   A
# 94   5.2  5.2  6.8  7.9  6.6  8.9  7.6  ...   M NaN    1  3.50  4.25  5.00   A
# 95   5.8  5.9  7.6  6.1  5.3  8.1  6.1  ...   M NaN    1  4.25  2.50  4.75   A
# 96   8.6  6.9  7.4  8.8  7.6  5.8  7.3  ...   F NaN    1  5.25  1.50  6.25   C
# 97   3.7  5.4  6.0  5.1  5.5  3.9  6.1  ...   F NaN    1  5.25  3.75  4.75   C
# 98   8.8  5.5  7.4  7.7  6.2  7.3  8.1  ...   M NaN  2NT  7.00  8.00  4.00   C
# 99   2.7  1.8  3.4  5.3  4.5  7.9  4.9  ...   M NaN    1  5.00  3.50  5.50   C
# 100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  ...   M NaN  2NT  5.25  2.50  4.25   C
#
# [10 rows x 55 columns]

# %% [markdown]
# ### 4.

# %%
dr["DT"].fillna(0, inplace = True)
dr
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT   DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F  0.0  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M  0.0    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M  0.0    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M  0.0    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M  0.0  2NT  4.25  4.50  5.00   A
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ..  ...  ...   ...   ...   ...  ..
# 96   8.6  6.9  7.4  8.8  7.6  5.8  7.3  ...   F  0.0    1  5.25  1.50  6.25   C
# 97   3.7  5.4  6.0  5.1  5.5  3.9  6.1  ...   F  0.0    1  5.25  3.75  4.75   C
# 98   8.8  5.5  7.4  7.7  6.2  7.3  8.1  ...   M  0.0  2NT  7.00  8.00  4.00   C
# 99   2.7  1.8  3.4  5.3  4.5  7.9  4.9  ...   M  0.0    1  5.00  3.50  5.50   C
# ...

# %% [markdown]
# 5. Thống kê dữ liệu thiếu cho biến T1 và hiệu chỉnh dữ liệu, lưu ý việc thay thế dữ liệu thiếu sử dụng phương pháp Mean.

# %%
dr["T1"].fillna(dr["T1"].mean(),inplace = True)
def fill(col):
  return dr[col].fillna(dr[col].mean(), inpleace = True)
dr.dtypes
is_float64 = dr.dtypes == float
dr_column_list = dr.columns[is_float64].tolist()
dr_column_list
dr.head()
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT   DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F  0.0  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M  0.0    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M  0.0    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M  0.0    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M  0.0  2NT  4.25  4.50  5.00   A
#
# [5 rows x 55 columns]

# %% [markdown]
# 6. Hãy thực hiện xử lý lần lượt tất cả dữ liệu thiếu cho các biến về điểm số còn lại.

# %% [markdown]
# *7. Tạo các biến TBM1, TBM2, TBM3 tương ứng với trung bình môn của các năm lớp 10, 11 và 12.* **Công thức tính: TBM = (T*2 + L + H + S + V*2 + X + D + N) / 10.**

# %%
for i in ["1","2","3"]:
  print("TBM" + i)
# Out:
# TBM1
# TBM2
# TBM3

# %%
for i in ["1","2","3"]:
  dr["TBM" + i] = (dr["T" + i]*2 + dr["L" + i] + dr["H" + i] + dr["S" + i] + dr["V" + i]*2 + dr["X" + i] + dr["D" + i] + dr["N" + i])/10
dr
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...   DH1   DH2   DH3  KT  TBM1  TBM2  TBM3
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...  3.25  3.25  4.50  A1  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...  6.00  4.00  3.50   C  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...  5.00  6.75  4.00   C  5.77  5.38  4.33
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...  4.25  4.25  5.25  D1  6.21  5.20  6.03
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...  4.25  4.50  5.00   A  6.50  6.36  7.01
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...  ..   ...   ...   ...
# 96   8.6  6.9  7.4  8.8  7.6  5.8  7.3  ...  5.25  1.50  6.25   C  7.43  7.42  7.04
# 97   3.7  5.4  6.0  5.1  5.5  3.9  6.1  ...  5.25  3.75  4.75   C  4.93  5.15  4.78
# 98   8.8  5.5  7.4  7.7  6.2  7.3  8.1  ...  7.00  8.00  4.00   C  7.05  7.84  7.92
# 99   2.7  1.8  3.4  5.3  4.5  7.9  4.9  ...  5.00  3.50  5.50   C  4.15  4.72  6.16
# ...

# %% [markdown]
# * **8.Tạo các biến xếp loại XL1, XL2 và XL3 dựa trên TBM1,TBM2 và TBM3 cho từng năm lớp 10, 11, 12 như sau:**
# **+ Nhỏ hơn 5.0 xếp loại: yếu (kí hiệu là Y), + Từ 5.0 đến dưới 6.5: trung bình (kí hiệu là TB). + Từ 6.5 đến dưới 8.0: khá (kí hiệu là K). + Từ 8.0 đến dưới 9.0: giỏi (kí hiệu là G). + Từ 9.0 trở lên: xuất sắc (kí hiệu là XS)**

# %%
for i in ["1", "2", "3"]:
  dr.loc[dr["TBM" + i] < 5, "XL" + i] = "Y"
  dr.loc[(dr["TBM" + i] >= 5) & (dr["TBM" + i] < 6.5), "XL" + i] = "TB"
  dr.loc[(dr["TBM" + i] >= 6.5) & (dr["TBM" + i] < 8), "XL" + i] = "K"
  dr.loc[(dr["TBM" + i] >= 8) & (dr["TBM" + i] < 9), "XL" + i] = "G"
  dr.loc[(dr["TBM" + i] >= 9), "XL" + i] = "XS"
dr
# Out:
#       T1   L1   H1   S1   V1  ...  us_TBM2  us_TBM3  US_TBM1  US_TBM2  US_TBM3
# STT                           ...
# 1    7.2  7.3  6.3  7.3  7.0  ...    3.016    2.824    2.800    3.016    2.824
# 2    5.4  3.9  3.9  4.0  5.4  ...    2.188    1.880    1.876    2.188    1.880
# 3    5.6  6.8  7.2  7.5  4.3  ...    2.152    1.732    2.308    2.152    1.732
# 4    6.6  6.4  5.3  6.9  5.4  ...    2.080    2.412    2.484    2.080    2.412
# 5    6.0  5.0  6.0  7.3  6.5  ...    2.544    2.804    2.600    2.544    2.804
# ..   ...  ...  ...  ...  ...  ...      ...      ...      ...      ...      ...
# 96   8.6  6.9  7.4  8.8  7.6  ...    2.968    2.816    2.972    2.968    2.816
# 97   3.7  5.4  6.0  5.1  5.5  ...    2.060    1.912    1.972    2.060    1.912
# 98   8.8  5.5  7.4  7.7  6.2  ...    3.136    3.168    2.820    3.136    3.168
# 99   2.7  1.8  3.4  5.3  4.5  ...    1.888    2.464    1.660    1.888    2.464
# ...

# %% [markdown]
# **9. Tạo các biến US_TBM1, US_TBM2 và US_TBM3 để chuyển điểm trung bình các năm lớp 10, 11 và 12 từ thang điểm 10 của Việt Nam sang thang điểm 4 của Mỹ. Sử dụng phương pháp Min-Max Normalization**

# %%
for i in ["1","2","3"]:
  dr["US_TBM" + i] = dr["TBM" + i]/10 * 4
dr.head()
# Out:
#       T1   L1   H1   S1   V1  ...  us_TBM2  us_TBM3  US_TBM1  US_TBM2  US_TBM3
# STT                           ...
# 1    7.2  7.3  6.3  7.3  7.0  ...    3.016    2.824    2.800    3.016    2.824
# 2    5.4  3.9  3.9  4.0  5.4  ...    2.188    1.880    1.876    2.188    1.880
# 3    5.6  6.8  7.2  7.5  4.3  ...    2.152    1.732    2.308    2.152    1.732
# 4    6.6  6.4  5.3  6.9  5.4  ...    2.080    2.412    2.484    2.080    2.412
# 5    6.0  5.0  6.0  7.3  6.5  ...    2.544    2.804    2.600    2.544    2.804
#
# [5 rows x 70 columns]

# %% [markdown]
# **10. Tạo biến kết quả xét tuyển (kí hiệu là KQXT) nhằm xác định sinh viên đậu (giá trị ―1‖) và rớt ( giá trị ―0‖) vào các khối dựa trên điểm DH1, DH2 và DH3 như sau
# Với khối A, A1 nếu [(DH1*2 + DH2 + DH3)/4] lớn hơn hoặc bằng 5.0 thì đậu, ngược lại là rớt.Với khối B nếu [(DH1 + DH2*2 + DH3)/4] lớn hơn hoặc bằng 5.0 thì đậu,ngược lại là rớt. Với khối khác nếu [(DH1+ DH2 + DH3)/3] lớn hơn hoặc bằng 5.0 thì đậu, ngược lại là rớt**

# %%
for i in dr["KT"].unique():
  str(i)
  iA1 = i == "A1"
  iA = i == "A"
  iB = i == "B"
  AA1 = (dr["DH1"]*2 + dr["DH2"] + dr["DH3"])/4
  B1 = (dr["DH1"] + dr["DH2"]*2 + dr["DH3"])/4
  oth = (dr["DH1"] + dr["DH2"] + dr["DH3"])/3
  
  dr.loc[(iA1 or iA) & (AA1 >= 5), "KQXT"] = 1
  dr.loc[(iA1 or iA) & (AA1 < 5), "KQXT"] = 0
  
  dr.loc[(iB) & (B1 >= 5), "KQXT"] = 1
  dr.loc[(iB) & (B1 < 5), "KQXT"] = 0
  
  dr.loc[(i != "A1" or i != "A" or i != "B") & (oth >= 5), "KQXT"] = 1
  dr.loc[(i != "A1" or i != "A" or i != "B") & (oth >= 5), "KQXT"] = 0
dr.head(10)
# Out:
#       T1   L1   H1   S1   V1  ...  us_TBM3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT                           ...
# 1    7.2  7.3  6.3  7.3  7.0  ...    2.824    2.800    3.016    2.824   0.0
# 2    5.4  3.9  3.9  4.0  5.4  ...    1.880    1.876    2.188    1.880   0.0
# 3    5.6  6.8  7.2  7.5  4.3  ...    1.732    2.308    2.152    1.732   0.0
# 4    6.6  6.4  5.3  6.9  5.4  ...    2.412    2.484    2.080    2.412   0.0
# 5    6.0  5.0  6.0  7.3  6.5  ...    2.804    2.600    2.544    2.804   0.0
# 6    9.3  7.6  7.9  8.6  7.0  ...    3.128    3.184    3.416    3.128   0.0
# 7    2.8  3.9  5.5  6.9  5.0  ...    2.096    1.960    2.240    2.096   0.0
# 8    8.3  6.0  7.6  5.1  7.5  ...    2.780    2.720    2.748    2.780   0.0
# 9    6.5  6.3  7.6  6.0  5.5  ...    2.636    2.492    2.688    2.636   0.0
# 10   7.3  5.9  4.7  7.1  6.7  ...    2.848    2.720    2.900    2.848   0.0
#
# [10 rows x 71 columns]

# %% [markdown]
# 11.

# %%
dr.to_csv('processed_dulieuxettuyendaihoc.csv')
